# %% [markdown]
# # Plot figure for webiste
#
# We want to show our RDD results on the website in a more suitable way. So we replot the time series figures with the new package **plotly** as well as the regression line.

# %% [markdown]
# ## 1. Load data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 1000)
from analysis.helpers.load import load_interventions, load_aggregated, load_topics
import pickle
import seaborn as sns
from scipy import stats
import math

import matplotlib
import statsmodels.formula.api as smf
import matplotlib.pyplot as mpl

import plotly.graph_objects as go
import plotly.express as px
import statsmodels.formula.api as smf
import statsmodels.api as sm
# %matplotlib inline

path = '../Covidpageviews/_includes/'

# %%
# load pageview data 
# we only plot the weekly data
with open('./data/keyword_pageviews_allcountry_weekly.pickle', 'rb') as handle:
    all_pageviews = pickle.load(handle)
all_pageviews['ja']['pageviews']['noncovid'].head(1)
# Out:
#             Hepatitis_C  Tuberculous_meningitis  Colorectal_cancer  \
# 2019-01-06          686                      78                935
#
#             Ovarian_cancer  Ulcerative_colitis  Type_2_diabetes  Cancer_pain  \
# 2019-01-06             318                3453              478          284
#
#             Hepatitis_E  Viral_hepatitis  Food_allergy  Cataract  \
# 2019-01-06          314              171           663       846
#
#             Cancer_vaccine  Seborrhoeic_dermatitis  Diabetes  World_AIDS_Day  \
# 2019-01-06              89                    1738      2526              51
#
#             Nummular_dermatitis  Hepatitis_A_vaccine  Low_back_pain  \
# 2019-01-06                  543                 13.0            453
#
#             Multi-drug-resistant_tuberculosis  Gestational_diabetes  Sepsis  \
# 2019-01-06                               20.0                   250    4464
#
#             Skin_allergy_test  Cancer_immunotherapy  Milk_allergy  \
# 2019-01-06                0.0                   188           418
#
#             University_of_Texas_MD_Anderson_Cancer_Center  Rhinitis  \
# 2019-01-06                                            0.0       455
#
#             Appendicitis  Type_1_diabetes  Flatulence  Asepsis  \
# 2019-01-06          2408              671        3466     18.0
#
#             Head_and_neck_cancer  Shivering  Allergic_rhinitis  \
# 2019-01-06                    72        878                242
#
#             Stasis_dermatitis  Oral_cancer  Penile_cancer  Pancreatic_cancer  \
# 2019-01-06                2.0          180            304               1606
#
#             Hepatitis_B_vaccine  Abdominal_pain  Tuskegee_syphilis_experiment  \
# 2019-01-06                   41             772                           348
#
#             Endometrial_cancer  Hypertension  Gestational_hypertension  \
# 2019-01-06                 187           705                       540
#
#             National_Cancer_Institute  Dana–Farber_Cancer_Institute  \
# 2019-01-06                         49                            34
#
#             Breast_cancer  Prostate_cancer  Malnutrition  Dermatitis  \
# 2019-01-06            961              867           491         501
#
#             HIV_vaccine  World_Cancer_Day  Colitis  Hives  \
# 2019-01-06          119              12.0      401   1730
#
#             Lymphocytic_choriomeningitis  Gallbladder_cancer  \
# 2019-01-06                          30.0                 326
#
#             Atopic_dermatitis  Rheumatoid_arthritis  \
# 2019-01-06               1692                  1455
#
#             National_Institute_of_Allergy_and_Infectious_Diseases  \
# 2019-01-06                                               10.0
#
#             Cervical_cancer  Laryngeal_cancer  Pulmonary_hypertension  \
# 2019-01-06              601               482                     102
#
#             Hepatitis_B  Testicular_cancer  Hepatitis  \
# 2019-01-06          858                741        980
#
#             Inflammatory_breast_cancer  Varicose_veins  Lung_cancer  \
# 2019-01-06                        72.0             297          939
#
#             White_coat_hypertension  Ischemic_colitis  Rash  Viral_meningitis  \
# 2019-01-06                      117               562   410               212
#
#             Hearing_loss  Squamous_cell_skin_cancer  Bladder_cancer  \
# 2019-01-06           905                        255             352
#
#             American_Cancer_Society  Gastroenteritis  Conjunctivitis  \
# 2019-01-06                      6.0             2570             483
#
#             Osteoarthritis  Athlete's_foot  \
# 2019-01-06              83             933
#
#             Hereditary_nonpolyposis_colorectal_cancer  Liver_cancer  \
# 2019-01-06                                         88           337
#
#             History_of_syphilis  Gout  Guatemala_syphilis_experiments  \
# 2019-01-06                  170  2817                             190
#
#             Neurosyphilis  Diabetes_management  Thyroid_cancer  Inflammation  \
# 2019-01-06            0.0                  105             295          1740
#
#             Complications_of_diabetes  Frequent_urination  \
# 2019-01-06                        107                 122
#
#             Systemic_lupus_erythematosus  Chickenpox  Contact_dermatitis  \
# 2019-01-06                          2614        4343                 561
#
#             Paralysis  Skin_cancer  Dehydration  Hepatitis_D  Constipation  \
# 2019-01-06        955           87          842           83          1216
#
#             Oral_allergy_syndrome  Neonatal_sepsis  Meningitis  Hyperhidrosis  \
# 2019-01-06                    306               52        1966            468
#
#             Hepatitis_B_virus  Irritant_diaper_dermatitis  Esophageal_cancer  \
# 2019-01-06                299                          86                522
#
#             Kidney_cancer  Portal_hypertension   HIV  Tuberculosis_management  \
# 2019-01-06            109                  177  4541                      0.0
#
#             Sleep_paralysis  Bruise  Vaginal_flatulence  \
# 2019-01-06             4247     625                  93
#
#             Mycobacterium_tuberculosis  Prediabetes  Childhood_cancer  \
# 2019-01-06                         684          154               149
#
#             Discoid_lupus_erythematosus  Tuberculosis  Allergy  \
# 2019-01-06                           82          4956     2315
#
#             Stomach_cancer  Cancer_stem_cell  Latex_allergy  Hypothyroidism  \
# 2019-01-06             839                92            226            1235
#
#             Cancer  Asthma  Noise-induced_hearing_loss  Hepatitis_A  Syphilis  \
# 2019-01-06    3039    1431                         663          367      6315
#
#             Autoimmune_hepatitis  Appendix_cancer  Diabetes_insipidus
# 2019-01-06                    93             1120                 506

# %%
all_pageviews['it']['pageviews']['covid'].T.index.names = ['index']
interventions = load_interventions('data/interventions.csv')

# %%
# As the correlation results show that the result of Italy is always good, so we decided to plot the result of Italy here too.
language = 'it'

# show all the events
# not in all countris/languages, like "English" only has "Mobility"&"Normalcy"
interventions[language].keys()
# Out:
# dict_keys(['1st case', '1st death', 'School closure', 'Public events banned', 'Lockdown', 'Mobility', 'Normalcy'])

# %% [markdown]
# ## 2.Combine all the data in one datafrmae without the datailed pagenames

# %%
# global variable

languages = ['sr', 'it', 'fr', 'en', 'nl', 'ko', 'de', 'fi', 'ja', 'no', 'sv', 'da']
categories = ['covid', 'noncovid','mental']

# %%
df = pd.DataFrame(columns = ['time','category','pageview','language','year'])

for l in languages:
    for c in categories:
        all_pageviews[l]['pageviews'][c].T.index.names = ['index']
        d1 = all_pageviews[l]['category'][c].merge(all_pageviews[l]['pageviews'][c].T,left_on = 'index',right_on = 'index')
        
        #compute the mean for each category
        d2 = d1.groupby('category').mean().T
        d2.columns.name = ''
        d2.index.names = ['time']
        pages = pd.DataFrame(all_pageviews[l]['pageviews'][c].mean(axis=1))
        pages.columns = [c]
        pages.index.names = ['time']
        d3 = pd.concat([pages,d2],axis=1)
        d3.reset_index(inplace=True)

        
        #drop time after 9.30.2019 for year 2019
        #d4 = d3.drop(range(273,365))
        d4 = d3.drop(range(39,52))
        d4 = d4.set_index('time').stack()
        d4 = d4.reset_index()
        d4.columns = ['time','category','pageview']
        d4['language'] = l
        d4['year'] = d4['time'].dt.year
        d4.time = d4['time'].apply(lambda x:x.replace(year = 2020))
        df = pd.concat([df,d4])


final = pd.DataFrame()
for l in languages:
    dftmp = df[df.language == l].copy()
    for e in interventions[l].keys():
        
        dftmp[e] = [0 if x < interventions[l][e] else 1 for x in dftmp.time]
    final = pd.concat([final,dftmp])

# %%
df = final
weekly_data = df.melt(id_vars=["time", "category","pageview","language","year"], 
        var_name="event", 
        value_name="intervention_flag")
weekly_data.pageview = np.log(weekly_data.pageview)
weekly_data.tail(1)
# Out:
#             time  category  pageview language  year     event  \
# 85175 2020-09-27  violence  3.109061       da  2020  Normalcy
#
#        intervention_flag
# 85175                1.0

# %%
weekly = pd.DataFrame()
for l in weekly_data.language.unique():
#     weekly_data['k'] = (weekly_data['time'] - pd.Series([interventions[l][e] for e in weekly_data[weekly_data['language']==l]['event'].unique()])).dt.days
    for c in weekly_data.category.unique():
        for e in interventions[l].keys():
            tmp = weekly_data[(weekly_data['language'] == l)*(weekly_data['category'] == c)*(weekly_data['event'] == e)].copy()
#             tmp['k'] = tmp['time']
            tmp['k'] = (tmp['time'] - pd.Series([interventions[l][e]]).item()).dt.days
            tmp_2019 = tmp[tmp['year'] == 2019].copy()
            tmp_2020 = tmp[tmp['year'] == 2020].copy()
            # tmp_2019['bestfit'] = sm.OLS(tmp_2019['covid'],sm.add_constant(tmp_2019[['k','intervention_flag']]).astype(float)).fit().fittedvalues 
            # tmp_2020['bestfit'] = sm.OLS(tmp_2020['covid'],sm.add_constant(tmp_2020[['k','intervention_flag']]).astype(float)).fit().fittedvalues 
            tmp_2019.loc[(tmp_2019.k>-80)*(tmp_2019.k<80),'bestfit'] = smf.ols(formula="pageview ~ k*intervention_flag", data=tmp_2019[(tmp_2019.k>-80)*(tmp_2019.k<80)]).fit().fittedvalues
            tmp_2020.loc[(tmp_2020.k>-80)*(tmp_2020.k<80),'bestfit'] = smf.ols(formula="pageview ~ k*intervention_flag", data=tmp_2020[(tmp_2020.k>-80)*(tmp_2020.k<80)]).fit().fittedvalues
            
            tmp = pd.concat([tmp_2019,tmp_2020])
            weekly = pd.concat([weekly,tmp])

# %% [markdown]
# ## 3. Time series plot
#
# Here ew will plot 4 different figures:
#  - Figure of 'Covid' for Italy over all events: it_time.html
#  - Figure of 'Mental' for Italy over all events: mental_it_time.html
#  - Figure of all categories and event 'Mobility' for Italy: cate_time_rdd.html
#  - Figure of 'Covid' and event 'Mobility' for all countries: coun_time_rdd.html

# %% [markdown]
# ### 3.1 Figure of 'Covid' for Italy over all events:
#
# **it_time.html**

# %%
# event = 'Mobility'
category = 'covid'
language = 'it'

df = daily[(daily['language'] == language)*(daily['category'] == category)].copy()

df['year'] = df['year'].astype(str)
fig=px.line(df, x='time', y="bestfit",color = 'year',animation_frame='event',line_group = 'intervention_flag')
fig.add_scatter(x=df[df['year'] == '2019']['time'], y=df[df['year'] == '2019']["pageview"],mode='markers',name = '2019')
fig.add_scatter(x=df[df['year'] == '2020']['time'], y=df[df['year'] == '2020']["pageview"],mode='markers',name = '2020')
fig.add_vline(x = df['event_time'].iloc[0],line_dash = 'dash')

for k in range(len(fig.frames)):
    fig.frames[k]['layout'].update(annotations = [{'text': str(list(interventions[language].values())[k].date()), 'x': list(interventions[language].values())[k], 'y': 1, 'yref': 'paper'}],
                                    shapes = [{'line': {'dash':'dash'},
                                          'type':'line',
                                          'x0': list(interventions[language].values())[k],
                                          'x1': list(interventions[language].values())[k],
                                          'xref': 'x',
                                          'y0': 0,
                                          'y1': 1,
                                          'yref': 'y domain'}],
#                                     sliders = [{'transition':{'duration':1000}}]
                                  )
#     fig.layout.sliders[0].steps[k].args.update(
#         frame = {'duration': 500, 'redraw': True},
#     )
fig.update_xaxes(
    dtick="M1",
    tickformat="%b")

fig.update_xaxes(rangeslider_visible=True,rangeslider_thickness = 0.05)

fig.update_layout(xaxis_title = 'Time', 
                  yaxis_title = 'Pageviews',
                  updatemenus = [{'buttons':[{'args': [None, {'frame': {'duration': 500,
                                           'redraw': True}, 'mode': 'immediate',
                                           'fromcurrent': True, 'transition':
                                           {'duration': 150, 'easing': 'linear'}}],
                                  'label': '&#9654;',
                                  'method': 'animate'},
                                 {'args': [[None], {'frame': {'duration': 500,
                                           'redraw': False}, 'mode': 'immediate',
                                           'fromcurrent': True, 'transition':
                                           {'duration': 150, 'easing': 'linear'}}],
                                  'label': '&#9724;',
                                  'method': 'animate'}]}])

fig.write_html(path+'it_time.html')

fig.show()
# Out:
# <div>                            <div id="116c1ed9-1c42-4dd3-9e21-a3be0daf2dd3" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("116c1ed9-1c42-4dd3-9e21-a3be0daf2dd3")) {                    Plotly.newPlot(                        "116c1ed9-1c42-4dd3-9e21-a3be0daf2dd3",                        [{"hovertemplate":"year=2019<br>event=1st case<br>intervention_flag=0.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"
df['year'] = df['year'].astype(str)
fig=px.line(df, x='time', y="bestfit",color = 'year',animation_frame='event',line_group = 'intervention_flag')
fig.add_scatter(x=df[df['year'] == '2019']['time'], y=df[df['year'] == '2019']["pageview"],mode='markers',name = '2019')
fig.add_scatter(x=df[df['year'] == '2020']['time'], y=df[df['year'] == '2020']["pageview"],mode='markers',name = '2020')
fig.add_vline(x = df['event_time'].iloc[0],line_dash = 'dash')

for k in range(len(fig.frames)):
    fig.frames[k]['layout'].update(annotations = [{'text': str(list(interventions[language].values())[k].date()), 'x': list(interventions[language].values())[k], 'y': 1, 'yref': 'paper'}],
                                    shapes = [{'line': {'dash':'dash'},
                                          'type':'line',
                                          'x0': list(interventions[language].values())[k],
                                          'x1': list(interventions[language].values())[k],
                                          'xref': 'x',
                                          'y0': 0,
                                          'y1': 1,
                                          'yref': 'y domain'}],
#                                     sliders = [{'transition':{'duration':1000}}]
                                  )
#     fig.layout.sliders[0].steps[k].args.update(
#         frame = {'duration': 500, 'redraw': True},
#     )
fig.update_xaxes(
    dtick="M1",
    tickformat="%b")

fig.update_xaxes(rangeslider_visible=True,rangeslider_thickness = 0.05)

fig.update_layout(xaxis_title = 'Time', 
                  yaxis_title = 'Pageviews',
                  updatemenus = [{'buttons':[{'args': [None, {'frame': {'duration': 500,
                                           'redraw': True}, 'mode': 'immediate',
                                           'fromcurrent': True, 'transition':
                                           {'duration': 150, 'easing': 'linear'}}],
                                  'label': '&#9654;',
                                  'method': 'animate'},
                                 {'args': [[None], {'frame': {'duration': 500,
                                           'redraw': False}, 'mode': 'immediate',
                                           'fromcurrent': True, 'transition':
                                           {'duration': 150, 'easing': 'linear'}}],
                                  'label': '&#9724;',
                                  'method': 'animate'}]}])

fig.write_html(path+'mental_it_time.html')

fig.show()
# Out:
# <div>                            <div id="e08d51a2-f840-435b-b943-b772ef456a12" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e08d51a2-f840-435b-b943-b772ef456a12")) {                    Plotly.newPlot(                        "e08d51a2-f840-435b-b943-b772ef456a12",                        [{"hovertemplate":"year=2019<br>event=1st case<br>intervention_flag=0.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":true,"x":["2020-01-06T00:00:00","2020-01-13T00:00:00","2020-01-20T00:00:00","2020-01-27T00:00:00"],"xaxis":"x","y":[6.682158535833769,6.712622318741566,6.743086101649364,6.773549884557162],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2019<br>event=1st case<br>intervention_flag=1.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":false,"x":["2020-02-03T00:00:00","2020-02-10T00:00:00","2020-02-17T00:00:00","2020-02-24T00:00:00","2020-03-03T00:00:00","2020-03-10T00:00:00","2020-03-17T00:00:00","2020-03-24T00:00:00","2020-03-31T00:00:00","2020-04-07T00:00:00","2020-04-14T00:00:00","2020-04-21T00:00:00","2020-04-28T00:00:00","2020-05-05T00:00:00","2020-05-12T00:00:00","2020-05-19T00:00:00","2020-05-26T00:00:00","2020-06-02T00:00:00","2020-06-09T00:00:00","2020-06-16T00:00:00","2020-06-23T00:00:00","2020-06-30T00:00:00","2020-07-07T00:00:00","2020-07-14T00:00:00","2020-07-21T00:00:00","2020-07-28T00:00:00","2020-08-04T00:00:00","2020-08-11T00:00:00","2020-08-18T00:00:00","2020-08-25T00:00:00","2020-09-01T00:00:00","2020-09-08T00:00:00","2020-09-15T00:00:00","2020-09-22T00:00:00","2020-09-29T00:00:00"],"xaxis":"x","y":[6.667645375306274,6.672951802039343,6.678258228772412,6.683564655505481,6.689629143200416,6.6949355699334845,6.700241996666553,6.705548423399622,6.710854850132691,6.716161276865759,6.721467703598828,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>event=1st case<br>intervention_flag=0.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":true,"x":["2020-01-05T00:00:00","2020-01-12T00:00:00","2020-01-19T00:00:00","2020-01-26T00:00:00"],"xaxis":"x","y":[6.59078836901817,6.685258530166287,6.779728691314405,6.874198852462523],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>event=1st case<br>intervention_flag=1.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":false,"x":["2020-02-02T00:00:00","2020-02-09T00:00:00","2020-02-16T00:00:00","2020-02-23T00:00:00","2020-03-01T00:00:00","2020-03-08T00:00:00","2020-03-15T00:00:00","2020-03-22T00:00:00","2020-03-29T00:00:00","2020-04-05T00:00:00","2020-04-12T00:00:00","2020-04-19T00:00:00","2020-04-26T00:00:00","2020-05-03T00:00:00","2020-05-10T00:00:00","2020-05-17T00:00:00","2020-05-24T00:00:00","2020-05-31T00:00:00","2020-06-07T00:00:00","2020-06-14T00:00:00","2020-06-21T00:00:00","2020-06-28T00:00:00","2020-07-05T00:00:00","2020-07-12T00:00:00","2020-07-19T00:00:00","2020-07-26T00:00:00","2020-08-02T00:00:00","2020-08-09T00:00:00","2020-08-16T00:00:00","2020-08-23T00:00:00","2020-08-30T00:00:00","2020-09-06T00:00:00","2020-09-13T00:00:00","2020-09-20T00:00:00","2020-09-27T00:00:00"],"xaxis":"x","y":[6.7344728859 ...

# %% [markdown]
# ### 3.3  Figure of all categories and event 'Mobility' for Italy
#
# **cate_time_rdd.html**

# %%
plot = go.Figure()
event = 'Mobility'
language = 'it'

# update categories
categories = final.category.unique()

for category in categories:
    df = daily[(daily['language'] == language)*(daily['category'] == category)*(daily['event'] == event)].copy()

    df['year'] = df['year'].astype(str)
    if category == 'covid':
        fig=px.line(df, x='time', y="bestfit",color = 'year',line_group = 'intervention_flag')
    else:
        fig=px.line(df, x='time', y="bestfit",color = 'year',line_group = 'intervention_flag').update_traces(visible=False, selector=lambda t: t.name in ["2019","2020"])
    fig.add_scatter(x=df[df['year'] == '2019']['time'], y=df[df['year'] == '2019']["pageview"],mode='markers',name = '2019',visible=False,)
    fig.add_scatter(x=df[df['year'] == '2020']['time'], y=df[df['year'] == '2020']["pageview"],mode='markers',name = '2020',visible=False,)
    plot.add_traces(fig.data)

plot.update_layout(
    updatemenus=[
        dict(
            active=1,
            buttons=list([
                dict(label="None",
                     method="update",
                     args=[{"visible": [False]*78},
                           {"title": "No Selection"}]),
            ])+list([
                dict(label=(str(k).capitalize()),
                     method='update',
                    args=[{'visible':[False]*6*i+[True]*6+[False]*6*(12-i)},
                          {'title':str(k).capitalize()}],)
                for i,k in enumerate(categories)
            ]),
            showactive = True,
            x = 1.08,
            xanchor = 'right',
            y = 1.2,
            yanchor = 'top',   
        )
    ])

plot.add_vline(x = interventions[language][event],line_dash = 'dash')
plot.add_annotation(x=interventions[language][event], y=1,yref="paper",text=str(interventions[language][event].date()))

plot.update_xaxes(
    dtick="M1",
    tickformat="%b")

plot.update_xaxes(rangeslider_visible=True,rangeslider_thickness = 0.05)
plot.update_layout(xaxis_title = 'Time', 
                  yaxis_title = 'Pageviews(Weekly)-Log',)

plot.write_html(path+'cate_time_rdd.html')
plot.show()
# Out:
# <div>                            <div id="58c08646-a86b-444e-b07b-3381b1475261" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58c08646-a86b-444e-b07b-3381b1475261")) {                    Plotly.newPlot(                        "58c08646-a86b-444e-b07b-3381b1475261",                        [{"hovertemplate":"year=2019<br>intervention_flag=0.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":true,"x":["2020-01-06T00:00:00","2020-01-13T00:00:00","2020-01-20T00:00:00","2020-01-27T00:00:00","2020-02-03T00:00:00","2020-02-10T00:00:00","2020-02-17T00:00:00","2020-02-24T00:00:00","2020-03-03T00:00:00","2020-03-10T00:00:00"],"xaxis":"x","y":[6.721889928686571,6.699230822386666,6.6765717160867615,6.653912609786857,6.631253503486952,6.608594397187047,6.585935290887142,6.563276184587237,6.537380063101632,6.514720956801727],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2019<br>intervention_flag=1.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2019","line":{"color":"#636efa","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2019","orientation":"v","showlegend":false,"x":["2020-03-17T00:00:00","2020-03-24T00:00:00","2020-03-31T00:00:00","2020-04-07T00:00:00","2020-04-14T00:00:00","2020-04-21T00:00:00","2020-04-28T00:00:00","2020-05-05T00:00:00","2020-05-12T00:00:00","2020-05-19T00:00:00","2020-05-26T00:00:00","2020-06-02T00:00:00","2020-06-09T00:00:00","2020-06-16T00:00:00","2020-06-23T00:00:00","2020-06-30T00:00:00","2020-07-07T00:00:00","2020-07-14T00:00:00","2020-07-21T00:00:00","2020-07-28T00:00:00","2020-08-04T00:00:00","2020-08-11T00:00:00","2020-08-18T00:00:00","2020-08-25T00:00:00","2020-09-01T00:00:00","2020-09-08T00:00:00","2020-09-15T00:00:00","2020-09-22T00:00:00","2020-09-29T00:00:00"],"xaxis":"x","y":[6.517548874040068,6.497544317014413,6.477539759988758,6.457535202963103,6.437530645937449,6.417526088911794,6.397521531886139,6.377516974860484,6.357512417834829,6.337507860809174,6.317503303783519,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null,null],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>intervention_flag=0.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":true,"x":["2020-01-05T00:00:00","2020-01-12T00:00:00","2020-01-19T00:00:00","2020-01-26T00:00:00","2020-02-02T00:00:00","2020-02-09T00:00:00","2020-02-16T00:00:00","2020-02-23T00:00:00","2020-03-01T00:00:00","2020-03-08T00:00:00"],"xaxis":"x","y":[6.489924725546414,6.7777270619465195,7.065529398346625,7.35333173474673,7.641134071146835,7.92893640754694,8.216738743947046,8.50454108034715,8.792343416747256,9.080145753147361],"yaxis":"y","type":"scatter"},{"hovertemplate":"year=2020<br>intervention_flag=1.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"2020","line":{"color":"#EF553B","dash":"solid"},"marker":{"symbol":"circle"},"mode":"lines","name":"2020","orientation":"v","showlegend":false,"x":["2020-03-15T00:00:00","2020-03-22T00:00:00","2020-03-29T00:00:00","2020-04-05T00:00:00","2020-04-12T00:00:00","2020-04-19T00:00:00","2020-04-26T00:00:00","2020-05-03T00:00:00","2020-05-10T00:00:00","2020-05-17T00:00:00","2020-05-24T00:00:00","2020-05-31T00:00:00","2020-06-07T00:00:00","2020-06-14T00:00:00","2020-06-21T00:00:00","2020-06-28T00:00:00","2020-07-05T00:00:00","2020-07-12T00:00:00","2020-07-19T00:00:00","2020-07-26T00:00:00","2020-08-02T00:00:00","2020-08-09T00:00:00","2020-08-16T00:00:00","2020-08-23T00:00:00","2020-08-30T00:00:00","2020 ...

# %% [markdown]
# ### 3.4  Figure of 'Covid' and event 'Mobility' for all countries
#
# **coun_time_rdd.html**

# %%
plot = go.Figure()
event = 'Mobility'
category = 'covid'

for language in languages:
    df = daily[(daily['language'] == language)*(daily['category'] == category)*(daily['event'] == event)].copy()

    df['year'] = df['year'].astype(str)
    if language == 'it':
        fig=px.line(df, x='time', y="bestfit",color = 'year',line_group = 'intervention_flag')
    else:
        fig=px.line(df, x='time', y="bestfit",color = 'year',line_group = 'intervention_flag').update_traces(visible=False, selector=lambda t: t.name in ["2019","2020"])
        
    fig.add_scatter(x=df[df['year'] == '2019']['time'], y=df[df['year'] == '2019']["pageview"],mode='markers',name = '2019',visible=False,)
    fig.add_scatter(x=df[df['year'] == '2020']['time'], y=df[df['year'] == '2020']["pageview"],mode='markers',name = '2020',visible=False,)
    plot.add_traces(fig.data)
    
plot.update_layout(
    updatemenus=[
        dict(
            active=1,
            buttons=list([
                dict(label="None",
                     method="update",
                     args=[{"visible": [False]*78},
                           {"title": "No Selection"}]),
            ])+list([
                dict(label=(str(k).capitalize()),
                     method='update',
                    args=[{'visible':[False]*6*i+[True]*6+[False]*6*(12-i)},
                          {'title':str(k).capitalize()}],)
                for i,k in enumerate(languages)
            ]),
            showactive = True,
            x = 1.08,
            xanchor = 'right',
            y = 1.2,
            yanchor = 'top',
            
        )
    ])

plot.update_xaxes(
    dtick="M1",
    tickformat="%b")

plot.update_xaxes(rangeslider_visible=True,rangeslider_thickness = 0.05)
plot.update_layout(xaxis_title = 'Time', 
                  yaxis_title = 'Pageviews(Weekly)-Log',)

plot.write_html(path+'coun_time_rdd.html')
plot.show()
# Out:
# <div>                            <div id="237a6a42-f18d-4f06-b4b7-d68535c7ad25" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                require(["plotly"], function(Plotly) {                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("237a6a42-f18d-4f06-b4b7-d68535c7ad25")) {                    Plotly.newPlot(                        "237a6a42-f18d-4f06-b4b7-d68535c7ad25",                        [{"hovertemplate":"year=2019<br>intervention_flag=0.0<br>time=%{x}<br>bestfit=%{y}<extra></extra>","legendgroup":"